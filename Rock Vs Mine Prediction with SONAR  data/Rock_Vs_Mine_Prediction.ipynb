# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df  = pd.read_csv('/content/Copy of sonar data.csv', header = None)

# %%
df.head(5)
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df[60].value_counts()  #--> Homogeneity of data M-> Mine, R-> Rock
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
df.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %% [markdown]
# # Seperating the data and labels

# %%
X =  df.drop(columns = 60, axis = 1)
Y  = df[60]

# %%
X.shape
# Out:
# (208, 60)

# %%
Y.shape
# Out:
# (208,)

# %%
print(X)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# # Splitting the data into test and train data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 42)

# %%
X_train.shape
# Out:
# (166, 60)

# %%
Y_train.shape
# Out:
# (166,)

# %%
X_test.shape
# Out:
# (42, 60)

# %%
print(X_train)
print(Y_train)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 97   0.0491  0.0279  0.0592  0.1270  0.1772  0.1908  0.2217  0.0768  0.1246
# 132  0.0968  0.0821  0.0629  0.0608  0.0617  0.1207  0.0944  0.4223  0.5744
# 201  0.0335  0.0258  0.0398  0.0570  0.0529  0.1091  0.1709  0.1684  0.1865
# 54   0.0132  0.0080  0.0188  0.0141  0.0436  0.0668  0.0609  0.0131  0.0899
# 105  0.0116  0.0179  0.0449  0.1096  0.1913  0.0924  0.0761  0.1092  0.0757
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 41   0.0093  0.0185  0.0056  0.0064  0.0260  0.0458  0.0470  0.0057  0.0425
# 116  0.0094  0.0333  0.0306  0.0376  0.1296  0.1795  0.1909  0.1692  0.1870
# 87   0.0856  0.0454  0.0382  0.0203  0.0385  0.0534  0.2140  0.3110  0.2837
# 78   0.0231  0.0351  0.0030  0.0304  0.0339  0.0860  0.1738  0.1351  0.1063
# 69   0.0216  0.0215  0.0273  0.0139  0.0357  0.0785  0.0906  0.0908  0.1151
#
# ...

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.8373493975903614

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on test data :  0.8571428571428571

# %% [markdown]
# ##Making a predictive system

# %%
input_data = (0.0331,0.0423,0.0474,0.0818,0.0835,0.0756,0.0374,0.0961,0.0548,0.0193,0.0897,0.1734,0.1936,0.2803,0.3313,0.5020,0.6360,0.7096,0.8333,0.8730,0.8073,0.7507,0.7526,0.7298,0.6177,0.4946,0.4531,0.4099,0.4540,0.4124,0.3139,0.3194,0.3692,0.3776,0.4469,0.4777,0.4716,0.4664,0.3893,0.4255,0.4064,0.3712,0.3863,0.2802,0.1283,0.1117,0.1303,0.0787,0.0436,0.0224,0.0133,0.0078,0.0174,0.0176,0.0038,0.0129,0.0066,0.0044,0.0134,0.0092)
# Changing the input_data to a numpy array
input_data = np.asarray(input_data)

# reshape the array
input_data = input_data.reshape(1,-1)

# prediction
predicted_value = model.predict(input_data)


if(predicted_value[0]=='R'):
  print('The object is a Rock')
else:
  print('The object is a Mine')
# Out:
# The object is a Rock

# %%
import numpy as np

def predict_rock_or_mine(model, input_data):
    """
    Predict whether the given input data represents a rock or a mine.

    Parameters:
    model: The trained machine learning model
    input_data: A tuple or list of feature values

    Returns:
    str: A string indicating whether the object is a rock or a mine
    """
    # Convert the input data to a numpy array
    input_data = np.asarray(input_data)

    # Reshape the array to match the model's expected input shape
    input_data = input_data.reshape(1, -1)

    # Make the prediction
    predicted_value = model.predict(input_data)

    # Return the result
    if predicted_value[0] == 'R':
        return 'The object is a Rock'
    else:
        return 'The object is a Mine'

# Example usage
input_data = (0.0331, 0.0423, 0.0474, 0.0818, 0.0835, 0.0756, 0.0374, 0.0961, 0.0548, 0.0193, 0.0897, 0.1734,
              0.1936, 0.2803, 0.3313, 0.5020, 0.6360, 0.7096, 0.8333, 0.8730, 0.8073, 0.7507, 0.7526, 0.7298,
              0.6177, 0.4946, 0.4531, 0.4099, 0.4540, 0.4124, 0.3139, 0.3194, 0.3692, 0.3776, 0.4469, 0.4777,
              0.4716, 0.4664, 0.3893, 0.4255, 0.4064, 0.3712, 0.3863, 0.2802, 0.1283, 0.1117, 0.1303, 0.0787,
              0.0436, 0.0224, 0.0133, 0.0078, 0.0174, 0.0176, 0.0038, 0.0129, 0.0066, 0.0044, 0.0134, 0.0092)

# Assuming 'model' is your trained machine learning model
result = predict_rock_or_mine(model, input_data)
print(result)
# Out:
# The object is a Rock

# %%
# calling the function
result = predict_rock_or_mine(model, [0.0409,0.0421,0.0573,0.0130,0.0183,0.1019,0.1054,0.1070,0.2302,0.2259,0.2373,0.3323,0.3827,0.4840,0.6812,0.7555,0.9522,0.9826,0.8871,0.8268,0.7561,0.8217,0.6967,0.6444,0.6948,0.8014,0.6053,0.6084,0.8877,0.8557,0.5563,0.2897,0.3638,0.4786,0.2908,0.0899,0.2043,0.1707,0.0407,0.1286,0.1581,0.2191,0.1701,0.0971,0.2217,0.2732,0.1874,0.1062,0.0665,0.0405,0.0113,0.0028,0.0036,0.0105,0.0120,0.0087,0.0061,0.0061,0.0030,0.0078])
print(result)
# Out:
# The object is a Mine
